# %%
# !git clone https://github.com/moana-yf/ssd.pytorch
# Out:
# Cloning into 'ssd.pytorch'...
# remote: Enumerating objects: 1444, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1444 (delta 0), reused 0 (delta 0), pack-reused 1441
# Receiving objects: 100% (1444/1444), 104.36 MiB | 24.46 MiB/s, done.
# Resolving deltas: 100% (863/863), done.

# %%
# %cd /content/ssd.pytorch
# Out:
# /content/ssd.pytorch

# %%
# !pip install opencv-python && \
pip install visdom && \
sh data/scripts/COCO2014.sh && \
sh data/scripts/VOC2007.sh && \
sh data/scripts/VOC2012.sh && \
# Out:
# Streaming output truncated to the last 5000 lines.
# VOCdevkit/VOC2012/SegmentationClass/2008_001885.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001895.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001896.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001926.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001966.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001971.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001992.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001997.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002032.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002043.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002064.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002066.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002067.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002073.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002079.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002080.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002123.png
# ...

# %%
# !mkdir weights

# %%
# %cd /content/ssd.pytorch/weights
# Out:
# /content/ssd.pytorch/weights

# %%
# !wget https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Out:
# --2023-05-19 03:46:37--  https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.168.8, 52.217.88.78, 52.216.53.184, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.168.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81938914 (78M) [binary/octet-stream]
# Saving to: ‘vgg16_reducedfc.pth’
#
# vgg16_reducedfc.pth 100%[===================>]  78.14M  15.6MB/s    in 6.2s
#
# 2023-05-19 03:46:45 (12.5 MB/s) - ‘vgg16_reducedfc.pth’ saved [81938914/81938914]

# %%
# %cd /content/ssd.pytorch/
# Out:
# /content/ssd.pytorch

# %%
# !cp /content/ssd.pytorch/data/coco_labels.txt /root/data/coco/coco_labels.txt

# %%
# !python train.py --batch_size 32 --lr 1e-4
# Out:
# /content/ssd.pytorch/ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)
# Loading base network...
# Initializing weights...
# /content/ssd.pytorch/train.py:228: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   init.xavier_uniform(param)
# Loading the dataset...
# epoch size:  3
# Training SSD on: VOC0712
# Using the specified args:
# Namespace(dataset='VOC', dataset_root='/root/data/VOCdevkit/', basenet='vgg16_reducedfc.pth', batch_size=32, resume=None, start_iter=0, num_workers=4, cuda=True, lr=0.0001, momentum=0.9, weight_decay=0.0005, gamma=0.1, visdom=False, save_folder='weights/')
# ...

# %%
# !cd weights && wget https://s3.amazonaws.com/amdegroot-models/ssd300_mAP_77.43_v2.pth
# Out:
# --2023-05-19 04:53:25--  https://s3.amazonaws.com/amdegroot-models/ssd300_mAP_77.43_v2.pth
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.128.48, 54.231.128.160, 52.216.62.16, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.128.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105151288 (100M) [application/x-www-form-urlencoded]
# Saving to: ‘ssd300_mAP_77.43_v2.pth’
#
# ssd300_mAP_77.43_v2 100%[===================>] 100.28M  15.4MB/s    in 7.7s
#
# 2023-05-19 04:53:34 (13.0 MB/s) - ‘ssd300_mAP_77.43_v2.pth’ saved [105151288/105151288]

# %%
# !python eval.py --trained_model weights/ssd300_COCO_5000.pth
# Out:
# Streaming output truncated to the last 5000 lines.
# im_detect: 3550/4952 0.244s
# im_detect: 3551/4952 0.230s
# /content/ssd.pytorch/layers/box_utils.py:216: UserWarning: An output with one or more elements was resized since it had shape [126], which does not match the required output shape [65]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at ../aten/src/ATen/native/Resize.cpp:26.)
#   torch.index_select(x1, 0, idx, out=xx1)
# ...

# %%
# !python eval.py --trained_model weights/VOC.pth
# !python eval.py
# Out:
# Streaming output truncated to the last 5000 lines.
#   torch.index_select(x1, 0, idx, out=xx1)
# /content/ssd.pytorch/layers/box_utils.py:217: UserWarning: An output with one or more elements was resized since it had shape [184], which does not match the required output shape [154]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at ../aten/src/ATen/native/Resize.cpp:26.)
#   torch.index_select(y1, 0, idx, out=yy1)
# ...

# %%
# !tar -zcvf /content/ssd.pytorch.tar.gz /content/ssd.pytorch
# Out:
# tar: Removing leading `/' from member names
# /content/ssd.pytorch/
# /content/ssd.pytorch/README.md
# /content/ssd.pytorch/layers/
# /content/ssd.pytorch/layers/functions/
# /content/ssd.pytorch/layers/functions/__init__.py
# /content/ssd.pytorch/layers/functions/detection.py
# /content/ssd.pytorch/layers/functions/prior_box.py
# /content/ssd.pytorch/layers/functions/__pycache__/
# /content/ssd.pytorch/layers/functions/__pycache__/__init__.cpython-310.pyc
# /content/ssd.pytorch/layers/functions/__pycache__/detection.cpython-310.pyc
# /content/ssd.pytorch/layers/functions/__pycache__/prior_box.cpython-310.pyc
# /content/ssd.pytorch/layers/box_utils.py
# /content/ssd.pytorch/layers/__init__.py
# /content/ssd.pytorch/layers/modules/
# /content/ssd.pytorch/layers/modules/l2norm.py
# /content/ssd.pytorch/layers/modules/__init__.py
# /content/ssd.pytorch/layers/modules/multibox_loss.py
# /content/ssd.pytorch/layers/modules/__pycache__/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/ssd.pytorch.tar.gz /content/drive/MyDrive
